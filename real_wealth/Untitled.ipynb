# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect

# %%
commands = []
employment = []
population = []
monthlylistings = []
medianincome = []
home_rentalprice = []

# %%
# with open(r'C:\Users\zgrin\OneDrive\Desktop\real-wealth-network-la\db\use.csv') as command_list:
#     for command in command_list:
#         commands.append(command)

engine = create_engine('sqlite:///realwealthnetwork.db')

# with engine.connect() as con:
#     ab = con.execute('DROP TABLE IF EXISTS "population";')
#     ac = con.execute('CREATE TABLE IF NOT EXISTS "population" ("id"INTEGER,"years"INTEGER,"population"INTEGER,"growth"INTEGER,"growth_rate" FLOAT);')
#     ad = con.execute('DROP TABLE IF EXISTS "monthlyListings";')
#     af = con.execute('CREATE TABLE IF NOT EXISTS "monthlyListings" ("id"INTEGER,"sizerank"INTEGER,"regionid"INTEGER,"regionname"TEXT,"regiontype"TEXT,"statename"TEXT,"date"TEXT,"totallistings"INTEGER);')
#     ag = con.execute('DROP TABLE IF EXISTS "medianIncome";')
#     ah = con.execute('CREATE TABLE IF NOT EXISTS "medianIncome" ("id"INTEGER,"years"INTEGER,"region"TEXT,"medianincome"INTEGER);')
#     ai = con.execute('DROP TABLE IF EXISTS "home_rentalPrice";')
#     aj = con.execute('CREATE TABLE IF NOT EXISTS "home_rentalPrice" ("id"INTEGER,"date"TEXT,"regionla"TEXT,"medianhomepricela"INTEGER,"medianRentalPriceLA"TEXT,"regionus"TEXT,"medianhomepriceus"	INTEGER,"medianRentalPriceUS"TEXT);')
#     ae = con.execute('DROP TABLE IF EXISTS "employment"')
#     ak = con.execute('CREATE TABLE IF NOT EXISTS "employment" ("id"INTEGER,"years"INTEGER,"periods"TEXT,"area"TEXT,"adjusted"TEXT,"preliminary"TEXT,"labor_force"INTEGER,"employment"INTEGER,"unemployment"INTEGER,"unemployment_rate"FLOAT);')
    
# for c in commands:
#     with engine.connect() as con:
#         con.execute(c)

with engine.connect() as con:
    rs = con.execute('SELECT * FROM employment')
    for r in rs:
        employment.append(r)
    rl = con.execute('SELECT * FROM population')
    for r in rl:
        population.append(r)
    rm = con.execute('SELECT * FROM monthlyListings')
    for r in rm:
        monthlylistings.append(r)
    rt = con.execute('SELECT * FROM home_rentalPrice')
    for r in rt:
        home_rentalprice.append(r)
    rx = con.execute('SELECT * FROM medianIncome')
    for r in rx:
        medianincome.append(r)

# %%
population = [list(el) for el in population]
employment = [list(el) for el in employment]
monthlylistings = [list(el) for el in monthlylistings]
home_rentalprice = [list(el) for el in home_rentalprice]
medianincome = [list(el) for el in medianincome]

# %%
labels = ['id', 'date', 'regionla', 'medianhomepricela', 'medianRentalPriceLA', 'regionus', 'medianhomepriceus', 'medianRentalPriceUS']
hrpdf = pd.DataFrame.from_records(home_rentalprice, columns=labels)

# %%
hrpdf.head()
# Out:
#    id     date            regionla  medianhomepricela medianRentalPriceLA  \
# 0   1  1996-04  Los Angeles County             160800                None
# 1   2  1996-05  Los Angeles County             160700                None
# 2   3  1996-06  Los Angeles County             160600                None
# 3   4  1996-07  Los Angeles County             160400                None
# 4   5  1996-08  Los Angeles County             160200                None
#
#         regionus  medianhomepriceus medianRentalPriceUS
# 0  United States             100000                None
# 1  United States             100100                None
# 2  United States             100300                None
# 3  United States             100500                None
# 4  United States             100800                None

# %%
homerentalpriceData = hrpdf.to_dict('records')

# %%
homerentalpriceData
# Out:
# [{'id': 1,
#   'date': '1996-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 100000,
#   'medianRentalPriceUS': None},
#  {'id': 2,
#   'date': '1996-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 100100,
#   'medianRentalPriceUS': None},
#  {'id': 3,
#   'date': '1996-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 100300,
#   'medianRentalPriceUS': None},
#  {'id': 4,
#   'date': '1996-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 100500,
#   'medianRentalPriceUS': None},
#  {'id': 5,
#   'date': '1996-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 100800,
#   'medianRentalPriceUS': None},
#  {'id': 6,
#   'date': '1996-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 101000,
#   'medianRentalPriceUS': None},
#  {'id': 7,
#   'date': '1996-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 101300,
#   'medianRentalPriceUS': None},
#  {'id': 8,
#   'date': '1996-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 101500,
#   'medianRentalPriceUS': None},
#  {'id': 9,
#   'date': '1996-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 160500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 101900,
#   'medianRentalPriceUS': None},
#  {'id': 10,
#   'date': '1997-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 102200,
#   'medianRentalPriceUS': None},
#  {'id': 11,
#   'date': '1997-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 102500,
#   'medianRentalPriceUS': None},
#  {'id': 12,
#   'date': '1997-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 102800,
#   'medianRentalPriceUS': None},
#  {'id': 13,
#   'date': '1997-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 103000,
#   'medianRentalPriceUS': None},
#  {'id': 14,
#   'date': '1997-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 103300,
#   'medianRentalPriceUS': None},
#  {'id': 15,
#   'date': '1997-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 103600,
#   'medianRentalPriceUS': None},
#  {'id': 16,
#   'date': '1997-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 161900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 104000,
#   'medianRentalPriceUS': None},
#  {'id': 17,
#   'date': '1997-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 162300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 104400,
#   'medianRentalPriceUS': None},
#  {'id': 18,
#   'date': '1997-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 162800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 104700,
#   'medianRentalPriceUS': None},
#  {'id': 19,
#   'date': '1997-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 163700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 105200,
#   'medianRentalPriceUS': None},
#  {'id': 20,
#   'date': '1997-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 164800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 105600,
#   'medianRentalPriceUS': None},
#  {'id': 21,
#   'date': '1997-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 166400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 106100,
#   'medianRentalPriceUS': None},
#  {'id': 22,
#   'date': '1998-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 168300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 106600,
#   'medianRentalPriceUS': None},
#  {'id': 23,
#   'date': '1998-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 170000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 107200,
#   'medianRentalPriceUS': None},
#  {'id': 24,
#   'date': '1998-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 171400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 107700,
#   'medianRentalPriceUS': None},
#  {'id': 25,
#   'date': '1998-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 172700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 108200,
#   'medianRentalPriceUS': None},
#  {'id': 26,
#   'date': '1998-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 173800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 108800,
#   'medianRentalPriceUS': None},
#  {'id': 27,
#   'date': '1998-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 174700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 109400,
#   'medianRentalPriceUS': None},
#  {'id': 28,
#   'date': '1998-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 175400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 110000,
#   'medianRentalPriceUS': None},
#  {'id': 29,
#   'date': '1998-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 176200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 110600,
#   'medianRentalPriceUS': None},
#  {'id': 30,
#   'date': '1998-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 177100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 111100,
#   'medianRentalPriceUS': None},
#  {'id': 31,
#   'date': '1998-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 178100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 111700,
#   'medianRentalPriceUS': None},
#  {'id': 32,
#   'date': '1998-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 179200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 112300,
#   'medianRentalPriceUS': None},
#  {'id': 33,
#   'date': '1998-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 180600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 112900,
#   'medianRentalPriceUS': None},
#  {'id': 34,
#   'date': '1999-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 182300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 113500,
#   'medianRentalPriceUS': None},
#  {'id': 35,
#   'date': '1999-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 183900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 114000,
#   'medianRentalPriceUS': None},
#  {'id': 36,
#   'date': '1999-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 185200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 114400,
#   'medianRentalPriceUS': None},
#  {'id': 37,
#   'date': '1999-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 186600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 114900,
#   'medianRentalPriceUS': None},
#  {'id': 38,
#   'date': '1999-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 188000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 115400,
#   'medianRentalPriceUS': None},
#  {'id': 39,
#   'date': '1999-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 189400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 116100,
#   'medianRentalPriceUS': None},
#  {'id': 40,
#   'date': '1999-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 190800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 116800,
#   'medianRentalPriceUS': None},
#  {'id': 41,
#   'date': '1999-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 192000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 117500,
#   'medianRentalPriceUS': None},
#  {'id': 42,
#   'date': '1999-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 193200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 118300,
#   'medianRentalPriceUS': None},
#  {'id': 43,
#   'date': '1999-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 194500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 119000,
#   'medianRentalPriceUS': None},
#  {'id': 44,
#   'date': '1999-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 195900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 119700,
#   'medianRentalPriceUS': None},
#  {'id': 45,
#   'date': '1999-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 197600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 120600,
#   'medianRentalPriceUS': None},
#  {'id': 46,
#   'date': '2000-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 199600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 121500,
#   'medianRentalPriceUS': None},
#  {'id': 47,
#   'date': '2000-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 201600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 122300,
#   'medianRentalPriceUS': None},
#  {'id': 48,
#   'date': '2000-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 203400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 123000,
#   'medianRentalPriceUS': None},
#  {'id': 49,
#   'date': '2000-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 205300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 123600,
#   'medianRentalPriceUS': None},
#  {'id': 50,
#   'date': '2000-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 207200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 124200,
#   'medianRentalPriceUS': None},
#  {'id': 51,
#   'date': '2000-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 209200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 124800,
#   'medianRentalPriceUS': None},
#  {'id': 52,
#   'date': '2000-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 211200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 125300,
#   'medianRentalPriceUS': None},
#  {'id': 53,
#   'date': '2000-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 213100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 125800,
#   'medianRentalPriceUS': None},
#  {'id': 54,
#   'date': '2000-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 215100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 126200,
#   'medianRentalPriceUS': None},
#  {'id': 55,
#   'date': '2000-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 217200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 126700,
#   'medianRentalPriceUS': None},
#  {'id': 56,
#   'date': '2000-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 219300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 127200,
#   'medianRentalPriceUS': None},
#  {'id': 57,
#   'date': '2000-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 221500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 127900,
#   'medianRentalPriceUS': None},
#  {'id': 58,
#   'date': '2001-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 223800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 128600,
#   'medianRentalPriceUS': None},
#  {'id': 59,
#   'date': '2001-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 226000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 129300,
#   'medianRentalPriceUS': None},
#  {'id': 60,
#   'date': '2001-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 228100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 129900,
#   'medianRentalPriceUS': None},
#  {'id': 61,
#   'date': '2001-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 230200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 130600,
#   'medianRentalPriceUS': None},
#  {'id': 62,
#   'date': '2001-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 232200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 131200,
#   'medianRentalPriceUS': None},
#  {'id': 63,
#   'date': '2001-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 234300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 131700,
#   'medianRentalPriceUS': None},
#  {'id': 64,
#   'date': '2001-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 236300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 132200,
#   'medianRentalPriceUS': None},
#  {'id': 65,
#   'date': '2001-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 238300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 132800,
#   'medianRentalPriceUS': None},
#  {'id': 66,
#   'date': '2001-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 240300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 133300,
#   'medianRentalPriceUS': None},
#  {'id': 67,
#   'date': '2001-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 242500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 133900,
#   'medianRentalPriceUS': None},
#  {'id': 68,
#   'date': '2001-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 244800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 134600,
#   'medianRentalPriceUS': None},
#  {'id': 69,
#   'date': '2001-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 247400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 135200,
#   'medianRentalPriceUS': None},
#  {'id': 70,
#   'date': '2002-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 250200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 136000,
#   'medianRentalPriceUS': None},
#  {'id': 71,
#   'date': '2002-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 253200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 136700,
#   'medianRentalPriceUS': None},
#  {'id': 72,
#   'date': '2002-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 256400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 137400,
#   'medianRentalPriceUS': None},
#  {'id': 73,
#   'date': '2002-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 259800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 138100,
#   'medianRentalPriceUS': None},
#  {'id': 74,
#   'date': '2002-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 263400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 138800,
#   'medianRentalPriceUS': None},
#  {'id': 75,
#   'date': '2002-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 267300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 139500,
#   'medianRentalPriceUS': None},
#  {'id': 76,
#   'date': '2002-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 271600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 140100,
#   'medianRentalPriceUS': None},
#  {'id': 77,
#   'date': '2002-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 276200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 140800,
#   'medianRentalPriceUS': None},
#  {'id': 78,
#   'date': '2002-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 281000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 141500,
#   'medianRentalPriceUS': None},
#  {'id': 79,
#   'date': '2002-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 285900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 142300,
#   'medianRentalPriceUS': None},
#  {'id': 80,
#   'date': '2002-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 291000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 143200,
#   'medianRentalPriceUS': None},
#  {'id': 81,
#   'date': '2002-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 296000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 144000,
#   'medianRentalPriceUS': None},
#  {'id': 82,
#   'date': '2003-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 300700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 144800,
#   'medianRentalPriceUS': None},
#  {'id': 83,
#   'date': '2003-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 305200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 145500,
#   'medianRentalPriceUS': None},
#  {'id': 84,
#   'date': '2003-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 309800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 146200,
#   'medianRentalPriceUS': None},
#  {'id': 85,
#   'date': '2003-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 314600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 147100,
#   'medianRentalPriceUS': None},
#  {'id': 86,
#   'date': '2003-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 319800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 147900,
#   'medianRentalPriceUS': None},
#  {'id': 87,
#   'date': '2003-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 325400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 148800,
#   'medianRentalPriceUS': None},
#  {'id': 88,
#   'date': '2003-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 331500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 149700,
#   'medianRentalPriceUS': None},
#  {'id': 89,
#   'date': '2003-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 337800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 150600,
#   'medianRentalPriceUS': None},
#  {'id': 90,
#   'date': '2003-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 344400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 151600,
#   'medianRentalPriceUS': None},
#  {'id': 91,
#   'date': '2003-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 351100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 152600,
#   'medianRentalPriceUS': None},
#  {'id': 92,
#   'date': '2003-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 358100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 153800,
#   'medianRentalPriceUS': None},
#  {'id': 93,
#   'date': '2003-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 365500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 154900,
#   'medianRentalPriceUS': None},
#  {'id': 94,
#   'date': '2004-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 373400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 156100,
#   'medianRentalPriceUS': None},
#  {'id': 95,
#   'date': '2004-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 381900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 157400,
#   'medianRentalPriceUS': None},
#  {'id': 96,
#   'date': '2004-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 391200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 158700,
#   'medianRentalPriceUS': None},
#  {'id': 97,
#   'date': '2004-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 401100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 160100,
#   'medianRentalPriceUS': None},
#  {'id': 98,
#   'date': '2004-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 411300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 161600,
#   'medianRentalPriceUS': None},
#  {'id': 99,
#   'date': '2004-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 421600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163100,
#   'medianRentalPriceUS': None},
#  {'id': 100,
#   'date': '2004-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 431400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 164800,
#   'medianRentalPriceUS': None},
#  {'id': 101,
#   'date': '2004-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 440400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 166400,
#   'medianRentalPriceUS': None},
#  {'id': 102,
#   'date': '2004-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 448800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 167900,
#   'medianRentalPriceUS': None},
#  {'id': 103,
#   'date': '2004-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 456300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 169300,
#   'medianRentalPriceUS': None},
#  {'id': 104,
#   'date': '2004-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 463000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 170700,
#   'medianRentalPriceUS': None},
#  {'id': 105,
#   'date': '2004-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 469100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 172000,
#   'medianRentalPriceUS': None},
#  {'id': 106,
#   'date': '2005-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 475000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 173200,
#   'medianRentalPriceUS': None},
#  {'id': 107,
#   'date': '2005-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 480800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 174400,
#   'medianRentalPriceUS': None},
#  {'id': 108,
#   'date': '2005-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 486800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 175700,
#   'medianRentalPriceUS': None},
#  {'id': 109,
#   'date': '2005-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 493100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 177100,
#   'medianRentalPriceUS': None},
#  {'id': 110,
#   'date': '2005-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 499700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 178700,
#   'medianRentalPriceUS': None},
#  {'id': 111,
#   'date': '2005-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 506700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 180300,
#   'medianRentalPriceUS': None},
#  {'id': 112,
#   'date': '2005-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 514300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 182000,
#   'medianRentalPriceUS': None},
#  {'id': 113,
#   'date': '2005-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 521800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 183700,
#   'medianRentalPriceUS': None},
#  {'id': 114,
#   'date': '2005-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 529400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 185300,
#   'medianRentalPriceUS': None},
#  {'id': 115,
#   'date': '2005-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 536900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 186800,
#   'medianRentalPriceUS': None},
#  {'id': 116,
#   'date': '2005-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 543700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 188200,
#   'medianRentalPriceUS': None},
#  {'id': 117,
#   'date': '2005-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 549800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 189600,
#   'medianRentalPriceUS': None},
#  {'id': 118,
#   'date': '2006-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 555200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 190900,
#   'medianRentalPriceUS': None},
#  {'id': 119,
#   'date': '2006-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 560000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 192100,
#   'medianRentalPriceUS': None},
#  {'id': 120,
#   'date': '2006-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 564700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 193300,
#   'medianRentalPriceUS': None},
#  {'id': 121,
#   'date': '2006-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 568900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 194500,
#   'medianRentalPriceUS': None},
#  {'id': 122,
#   'date': '2006-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 572500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 195500,
#   'medianRentalPriceUS': None},
#  {'id': 123,
#   'date': '2006-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 575100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 196600,
#   'medianRentalPriceUS': None},
#  {'id': 124,
#   'date': '2006-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 576200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 197500,
#   'medianRentalPriceUS': None},
#  {'id': 125,
#   'date': '2006-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 575300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 198200,
#   'medianRentalPriceUS': None},
#  {'id': 126,
#   'date': '2006-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 573300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 198700,
#   'medianRentalPriceUS': None},
#  {'id': 127,
#   'date': '2006-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 571100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199100,
#   'medianRentalPriceUS': None},
#  {'id': 128,
#   'date': '2006-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 568500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199300,
#   'medianRentalPriceUS': None},
#  {'id': 129,
#   'date': '2006-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 566000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199500,
#   'medianRentalPriceUS': None},
#  {'id': 130,
#   'date': '2007-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 563700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199700,
#   'medianRentalPriceUS': None},
#  {'id': 131,
#   'date': '2007-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 561400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199900,
#   'medianRentalPriceUS': None},
#  {'id': 132,
#   'date': '2007-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 558800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 200100,
#   'medianRentalPriceUS': None},
#  {'id': 133,
#   'date': '2007-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 555700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 200400,
#   'medianRentalPriceUS': None},
#  {'id': 134,
#   'date': '2007-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 552100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 200500,
#   'medianRentalPriceUS': None},
#  {'id': 135,
#   'date': '2007-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 548000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 200000,
#   'medianRentalPriceUS': None},
#  {'id': 136,
#   'date': '2007-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 543100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 199200,
#   'medianRentalPriceUS': None},
#  {'id': 137,
#   'date': '2007-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 536900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 198400,
#   'medianRentalPriceUS': None},
#  {'id': 138,
#   'date': '2007-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 530300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 197600,
#   'medianRentalPriceUS': None},
#  {'id': 139,
#   'date': '2007-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 523700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 196700,
#   'medianRentalPriceUS': None},
#  {'id': 140,
#   'date': '2007-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 517100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 195700,
#   'medianRentalPriceUS': None},
#  {'id': 141,
#   'date': '2007-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 510400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 194600,
#   'medianRentalPriceUS': None},
#  {'id': 142,
#   'date': '2008-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 503500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 193300,
#   'medianRentalPriceUS': None},
#  {'id': 143,
#   'date': '2008-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 495700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 191900,
#   'medianRentalPriceUS': None},
#  {'id': 144,
#   'date': '2008-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 486700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 190400,
#   'medianRentalPriceUS': None},
#  {'id': 145,
#   'date': '2008-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 476000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 188800,
#   'medianRentalPriceUS': None},
#  {'id': 146,
#   'date': '2008-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 464800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 187000,
#   'medianRentalPriceUS': None},
#  {'id': 147,
#   'date': '2008-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 454000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 185100,
#   'medianRentalPriceUS': None},
#  {'id': 148,
#   'date': '2008-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 445300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 183400,
#   'medianRentalPriceUS': None},
#  {'id': 149,
#   'date': '2008-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 438600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 181600,
#   'medianRentalPriceUS': None},
#  {'id': 150,
#   'date': '2008-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 433200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 180000,
#   'medianRentalPriceUS': None},
#  {'id': 151,
#   'date': '2008-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 427800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 178500,
#   'medianRentalPriceUS': None},
#  {'id': 152,
#   'date': '2008-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 422800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 177000,
#   'medianRentalPriceUS': None},
#  {'id': 153,
#   'date': '2008-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 418000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 175600,
#   'medianRentalPriceUS': None},
#  {'id': 154,
#   'date': '2009-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 413800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 174300,
#   'medianRentalPriceUS': None},
#  {'id': 155,
#   'date': '2009-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 409300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 173000,
#   'medianRentalPriceUS': None},
#  {'id': 156,
#   'date': '2009-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 404200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 171600,
#   'medianRentalPriceUS': None},
#  {'id': 157,
#   'date': '2009-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 398400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 170100,
#   'medianRentalPriceUS': None},
#  {'id': 158,
#   'date': '2009-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 392200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 168500,
#   'medianRentalPriceUS': None},
#  {'id': 159,
#   'date': '2009-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 387400,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 166900,
#   'medianRentalPriceUS': None},
#  {'id': 160,
#   'date': '2009-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 385700,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 165700,
#   'medianRentalPriceUS': None},
#  {'id': 161,
#   'date': '2009-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 386000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 164700,
#   'medianRentalPriceUS': None},
#  {'id': 162,
#   'date': '2009-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 387000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 164000,
#   'medianRentalPriceUS': None},
#  {'id': 163,
#   'date': '2009-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 388500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163400,
#   'medianRentalPriceUS': None},
#  {'id': 164,
#   'date': '2009-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 389900,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163100,
#   'medianRentalPriceUS': None},
#  {'id': 165,
#   'date': '2009-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 391300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163000,
#   'medianRentalPriceUS': None},
#  {'id': 166,
#   'date': '2010-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 392500,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163000,
#   'medianRentalPriceUS': None},
#  {'id': 167,
#   'date': '2010-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 393100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 163200,
#   'medianRentalPriceUS': None},
#  {'id': 168,
#   'date': '2010-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 392100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 162800,
#   'medianRentalPriceUS': None},
#  {'id': 169,
#   'date': '2010-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 392000,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 161900,
#   'medianRentalPriceUS': None},
#  {'id': 170,
#   'date': '2010-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 393300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 161500,
#   'medianRentalPriceUS': None},
#  {'id': 171,
#   'date': '2010-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 393200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 161400,
#   'medianRentalPriceUS': None},
#  {'id': 172,
#   'date': '2010-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 390300,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 160900,
#   'medianRentalPriceUS': None},
#  {'id': 173,
#   'date': '2010-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 388200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 160200,
#   'medianRentalPriceUS': None},
#  {'id': 174,
#   'date': '2010-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 386200,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 159400,
#   'medianRentalPriceUS': None},
#  {'id': 175,
#   'date': '2010-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 384100,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 158500,
#   'medianRentalPriceUS': None},
#  {'id': 176,
#   'date': '2010-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 382100,
#   'medianRentalPriceLA': '2176',
#   'regionus': 'United States',
#   'medianhomepriceus': 157600,
#   'medianRentalPriceUS': '1250'},
#  {'id': 177,
#   'date': '2010-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 380300,
#   'medianRentalPriceLA': '2160',
#   'regionus': 'United States',
#   'medianhomepriceus': 156600,
#   'medianRentalPriceUS': '1248'},
#  {'id': 178,
#   'date': '2011-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 377400,
#   'medianRentalPriceLA': '2153',
#   'regionus': 'United States',
#   'medianhomepriceus': 155300,
#   'medianRentalPriceUS': '1245'},
#  {'id': 179,
#   'date': '2011-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 374600,
#   'medianRentalPriceLA': '2148',
#   'regionus': 'United States',
#   'medianhomepriceus': 154300,
#   'medianRentalPriceUS': '1240'},
#  {'id': 180,
#   'date': '2011-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 372500,
#   'medianRentalPriceLA': '2146',
#   'regionus': 'United States',
#   'medianhomepriceus': 153500,
#   'medianRentalPriceUS': '1236'},
#  {'id': 181,
#   'date': '2011-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 370400,
#   'medianRentalPriceLA': '2148',
#   'regionus': 'United States',
#   'medianhomepriceus': 152900,
#   'medianRentalPriceUS': '1234'},
#  {'id': 182,
#   'date': '2011-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 368000,
#   'medianRentalPriceLA': '2154',
#   'regionus': 'United States',
#   'medianhomepriceus': 152300,
#   'medianRentalPriceUS': '1236'},
#  {'id': 183,
#   'date': '2011-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 366300,
#   'medianRentalPriceLA': '2161',
#   'regionus': 'United States',
#   'medianhomepriceus': 151600,
#   'medianRentalPriceUS': '1241'},
#  {'id': 184,
#   'date': '2011-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 364600,
#   'medianRentalPriceLA': '2168',
#   'regionus': 'United States',
#   'medianhomepriceus': 151000,
#   'medianRentalPriceUS': '1248'},
#  {'id': 185,
#   'date': '2011-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 361700,
#   'medianRentalPriceLA': '2172',
#   'regionus': 'United States',
#   'medianhomepriceus': 150500,
#   'medianRentalPriceUS': '1252'},
#  {'id': 186,
#   'date': '2011-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 358800,
#   'medianRentalPriceLA': '2174',
#   'regionus': 'United States',
#   'medianhomepriceus': 150000,
#   'medianRentalPriceUS': '1254'},
#  {'id': 187,
#   'date': '2011-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 356400,
#   'medianRentalPriceLA': '2176',
#   'regionus': 'United States',
#   'medianhomepriceus': 149600,
#   'medianRentalPriceUS': '1250'},
#  {'id': 188,
#   'date': '2011-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 354100,
#   'medianRentalPriceLA': '2174',
#   'regionus': 'United States',
#   'medianhomepriceus': 149400,
#   'medianRentalPriceUS': '1244'},
#  {'id': 189,
#   'date': '2011-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 352300,
#   'medianRentalPriceLA': '2165',
#   'regionus': 'United States',
#   'medianhomepriceus': 149200,
#   'medianRentalPriceUS': '1237'},
#  {'id': 190,
#   'date': '2012-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 351300,
#   'medianRentalPriceLA': '2150',
#   'regionus': 'United States',
#   'medianhomepriceus': 148900,
#   'medianRentalPriceUS': '1232'},
#  {'id': 191,
#   'date': '2012-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 350900,
#   'medianRentalPriceLA': '2142',
#   'regionus': 'United States',
#   'medianhomepriceus': 148700,
#   'medianRentalPriceUS': '1229'},
#  {'id': 192,
#   'date': '2012-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 351700,
#   'medianRentalPriceLA': '2139',
#   'regionus': 'United States',
#   'medianhomepriceus': 148900,
#   'medianRentalPriceUS': '1227'},
#  {'id': 193,
#   'date': '2012-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 354200,
#   'medianRentalPriceLA': '2141',
#   'regionus': 'United States',
#   'medianhomepriceus': 149200,
#   'medianRentalPriceUS': '1226'},
#  {'id': 194,
#   'date': '2012-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 357500,
#   'medianRentalPriceLA': '2145',
#   'regionus': 'United States',
#   'medianhomepriceus': 149600,
#   'medianRentalPriceUS': '1230'},
#  {'id': 195,
#   'date': '2012-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 360000,
#   'medianRentalPriceLA': '2150',
#   'regionus': 'United States',
#   'medianhomepriceus': 149900,
#   'medianRentalPriceUS': '1235'},
#  {'id': 196,
#   'date': '2012-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 362100,
#   'medianRentalPriceLA': '2157',
#   'regionus': 'United States',
#   'medianhomepriceus': 150300,
#   'medianRentalPriceUS': '1243'},
#  {'id': 197,
#   'date': '2012-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 363900,
#   'medianRentalPriceLA': '2158',
#   'regionus': 'United States',
#   'medianhomepriceus': 150900,
#   'medianRentalPriceUS': '1249'},
#  {'id': 198,
#   'date': '2012-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 366100,
#   'medianRentalPriceLA': '2163',
#   'regionus': 'United States',
#   'medianhomepriceus': 151500,
#   'medianRentalPriceUS': '1252'},
#  {'id': 199,
#   'date': '2012-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 369000,
#   'medianRentalPriceLA': '2163',
#   'regionus': 'United States',
#   'medianhomepriceus': 152000,
#   'medianRentalPriceUS': '1252'},
#  {'id': 200,
#   'date': '2012-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 373600,
#   'medianRentalPriceLA': '2163',
#   'regionus': 'United States',
#   'medianhomepriceus': 152400,
#   'medianRentalPriceUS': '1250'},
#  {'id': 201,
#   'date': '2012-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 377900,
#   'medianRentalPriceLA': '2163',
#   'regionus': 'United States',
#   'medianhomepriceus': 153100,
#   'medianRentalPriceUS': '1248'},
#  {'id': 202,
#   'date': '2013-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 381400,
#   'medianRentalPriceLA': '2166',
#   'regionus': 'United States',
#   'medianhomepriceus': 153800,
#   'medianRentalPriceUS': '1246'},
#  {'id': 203,
#   'date': '2013-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 386400,
#   'medianRentalPriceLA': '2170',
#   'regionus': 'United States',
#   'medianhomepriceus': 154400,
#   'medianRentalPriceUS': '1244'},
#  {'id': 204,
#   'date': '2013-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 394300,
#   'medianRentalPriceLA': '2176',
#   'regionus': 'United States',
#   'medianhomepriceus': 155200,
#   'medianRentalPriceUS': '1242'},
#  {'id': 205,
#   'date': '2013-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 402300,
#   'medianRentalPriceLA': '2184',
#   'regionus': 'United States',
#   'medianhomepriceus': 156200,
#   'medianRentalPriceUS': '1243'},
#  {'id': 206,
#   'date': '2013-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 410000,
#   'medianRentalPriceLA': '2192',
#   'regionus': 'United States',
#   'medianhomepriceus': 157100,
#   'medianRentalPriceUS': '1249'},
#  {'id': 207,
#   'date': '2013-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 417500,
#   'medianRentalPriceLA': '2197',
#   'regionus': 'United States',
#   'medianhomepriceus': 158100,
#   'medianRentalPriceUS': '1258'},
#  {'id': 208,
#   'date': '2013-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 424500,
#   'medianRentalPriceLA': '2207',
#   'regionus': 'United States',
#   'medianhomepriceus': 159300,
#   'medianRentalPriceUS': '1269'},
#  {'id': 209,
#   'date': '2013-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 430500,
#   'medianRentalPriceLA': '2220',
#   'regionus': 'United States',
#   'medianhomepriceus': 160300,
#   'medianRentalPriceUS': '1277'},
#  {'id': 210,
#   'date': '2013-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 435300,
#   'medianRentalPriceLA': '2235',
#   'regionus': 'United States',
#   'medianhomepriceus': 161200,
#   'medianRentalPriceUS': '1283'},
#  {'id': 211,
#   'date': '2013-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 438700,
#   'medianRentalPriceLA': '2249',
#   'regionus': 'United States',
#   'medianhomepriceus': 162200,
#   'medianRentalPriceUS': '1286'},
#  {'id': 212,
#   'date': '2013-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 441300,
#   'medianRentalPriceLA': '2254',
#   'regionus': 'United States',
#   'medianhomepriceus': 163000,
#   'medianRentalPriceUS': '1286'},
#  {'id': 213,
#   'date': '2013-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 443200,
#   'medianRentalPriceLA': '2253',
#   'regionus': 'United States',
#   'medianhomepriceus': 163700,
#   'medianRentalPriceUS': '1284'},
#  {'id': 214,
#   'date': '2014-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 444900,
#   'medianRentalPriceLA': '2243',
#   'regionus': 'United States',
#   'medianhomepriceus': 164500,
#   'medianRentalPriceUS': '1279'},
#  {'id': 215,
#   'date': '2014-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 447300,
#   'medianRentalPriceLA': '2234',
#   'regionus': 'United States',
#   'medianhomepriceus': 165100,
#   'medianRentalPriceUS': '1272'},
#  {'id': 216,
#   'date': '2014-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 450300,
#   'medianRentalPriceLA': '2230',
#   'regionus': 'United States',
#   'medianhomepriceus': 165800,
#   'medianRentalPriceUS': '1267'},
#  {'id': 217,
#   'date': '2014-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 453200,
#   'medianRentalPriceLA': '2230',
#   'regionus': 'United States',
#   'medianhomepriceus': 166600,
#   'medianRentalPriceUS': '1264'},
#  {'id': 218,
#   'date': '2014-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 455800,
#   'medianRentalPriceLA': '2233',
#   'regionus': 'United States',
#   'medianhomepriceus': 167300,
#   'medianRentalPriceUS': '1265'},
#  {'id': 219,
#   'date': '2014-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 458800,
#   'medianRentalPriceLA': '2239',
#   'regionus': 'United States',
#   'medianhomepriceus': 167900,
#   'medianRentalPriceUS': '1269'},
#  {'id': 220,
#   'date': '2014-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 461800,
#   'medianRentalPriceLA': '2256',
#   'regionus': 'United States',
#   'medianhomepriceus': 168700,
#   'medianRentalPriceUS': '1279'},
#  {'id': 221,
#   'date': '2014-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 463700,
#   'medianRentalPriceLA': '2278',
#   'regionus': 'United States',
#   'medianhomepriceus': 169400,
#   'medianRentalPriceUS': '1292'},
#  {'id': 222,
#   'date': '2014-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 464800,
#   'medianRentalPriceLA': '2303',
#   'regionus': 'United States',
#   'medianhomepriceus': 170000,
#   'medianRentalPriceUS': '1306'},
#  {'id': 223,
#   'date': '2014-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 466200,
#   'medianRentalPriceLA': '2324',
#   'regionus': 'United States',
#   'medianhomepriceus': 170600,
#   'medianRentalPriceUS': '1315'},
#  {'id': 224,
#   'date': '2014-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 467300,
#   'medianRentalPriceLA': '2346',
#   'regionus': 'United States',
#   'medianhomepriceus': 171100,
#   'medianRentalPriceUS': '1319'},
#  {'id': 225,
#   'date': '2014-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 469300,
#   'medianRentalPriceLA': '2367',
#   'regionus': 'United States',
#   'medianhomepriceus': 171700,
#   'medianRentalPriceUS': '1321'},
#  {'id': 226,
#   'date': '2015-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 472800,
#   'medianRentalPriceLA': '2380',
#   'regionus': 'United States',
#   'medianhomepriceus': 172400,
#   'medianRentalPriceUS': '1321'},
#  {'id': 227,
#   'date': '2015-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 476800,
#   'medianRentalPriceLA': '2389',
#   'regionus': 'United States',
#   'medianhomepriceus': 173100,
#   'medianRentalPriceUS': '1322'},
#  {'id': 228,
#   'date': '2015-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 479600,
#   'medianRentalPriceLA': '2401',
#   'regionus': 'United States',
#   'medianhomepriceus': 173800,
#   'medianRentalPriceUS': '1326'},
#  {'id': 229,
#   'date': '2015-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 482200,
#   'medianRentalPriceLA': '2414',
#   'regionus': 'United States',
#   'medianhomepriceus': 174600,
#   'medianRentalPriceUS': '1332'},
#  {'id': 230,
#   'date': '2015-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 485100,
#   'medianRentalPriceLA': '2429',
#   'regionus': 'United States',
#   'medianhomepriceus': 175500,
#   'medianRentalPriceUS': '1341'},
#  {'id': 231,
#   'date': '2015-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 488100,
#   'medianRentalPriceLA': '2439',
#   'regionus': 'United States',
#   'medianhomepriceus': 176300,
#   'medianRentalPriceUS': '1352'},
#  {'id': 232,
#   'date': '2015-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 491000,
#   'medianRentalPriceLA': '2451',
#   'regionus': 'United States',
#   'medianhomepriceus': 177200,
#   'medianRentalPriceUS': '1363'},
#  {'id': 233,
#   'date': '2015-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 493800,
#   'medianRentalPriceLA': '2462',
#   'regionus': 'United States',
#   'medianhomepriceus': 177800,
#   'medianRentalPriceUS': '1372'},
#  {'id': 234,
#   'date': '2015-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 497000,
#   'medianRentalPriceLA': '2468',
#   'regionus': 'United States',
#   'medianhomepriceus': 178500,
#   'medianRentalPriceUS': '1376'},
#  {'id': 235,
#   'date': '2015-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 500600,
#   'medianRentalPriceLA': '2471',
#   'regionus': 'United States',
#   'medianhomepriceus': 179400,
#   'medianRentalPriceUS': '1373'},
#  {'id': 236,
#   'date': '2015-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 504000,
#   'medianRentalPriceLA': '2471',
#   'regionus': 'United States',
#   'medianhomepriceus': 180300,
#   'medianRentalPriceUS': '1366'},
#  {'id': 237,
#   'date': '2015-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 507900,
#   'medianRentalPriceLA': '2474',
#   'regionus': 'United States',
#   'medianhomepriceus': 181100,
#   'medianRentalPriceUS': '1359'},
#  {'id': 238,
#   'date': '2016-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 512200,
#   'medianRentalPriceLA': '2483',
#   'regionus': 'United States',
#   'medianhomepriceus': 181900,
#   'medianRentalPriceUS': '1359'},
#  {'id': 239,
#   'date': '2016-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 515200,
#   'medianRentalPriceLA': '2490',
#   'regionus': 'United States',
#   'medianhomepriceus': 182800,
#   'medianRentalPriceUS': '1361'},
#  {'id': 240,
#   'date': '2016-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 517800,
#   'medianRentalPriceLA': '2499',
#   'regionus': 'United States',
#   'medianhomepriceus': 183700,
#   'medianRentalPriceUS': '1368'},
#  {'id': 241,
#   'date': '2016-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 520700,
#   'medianRentalPriceLA': '2506',
#   'regionus': 'United States',
#   'medianhomepriceus': 184800,
#   'medianRentalPriceUS': '1372'},
#  {'id': 242,
#   'date': '2016-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 522800,
#   'medianRentalPriceLA': '2518',
#   'regionus': 'United States',
#   'medianhomepriceus': 185800,
#   'medianRentalPriceUS': '1380'},
#  {'id': 243,
#   'date': '2016-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 525000,
#   'medianRentalPriceLA': '2531',
#   'regionus': 'United States',
#   'medianhomepriceus': 187000,
#   'medianRentalPriceUS': '1386'},
#  {'id': 244,
#   'date': '2016-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 528600,
#   'medianRentalPriceLA': '2542',
#   'regionus': 'United States',
#   'medianhomepriceus': 187900,
#   'medianRentalPriceUS': '1391'},
#  {'id': 245,
#   'date': '2016-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 533400,
#   'medianRentalPriceLA': '2552',
#   'regionus': 'United States',
#   'medianhomepriceus': 189100,
#   'medianRentalPriceUS': '1392'},
#  {'id': 246,
#   'date': '2016-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 538300,
#   'medianRentalPriceLA': '2563',
#   'regionus': 'United States',
#   'medianhomepriceus': 190400,
#   'medianRentalPriceUS': '1393'},
#  {'id': 247,
#   'date': '2016-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 542000,
#   'medianRentalPriceLA': '2575',
#   'regionus': 'United States',
#   'medianhomepriceus': 191700,
#   'medianRentalPriceUS': '1392'},
#  {'id': 248,
#   'date': '2016-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 545200,
#   'medianRentalPriceLA': '2583',
#   'regionus': 'United States',
#   'medianhomepriceus': 192800,
#   'medianRentalPriceUS': '1391'},
#  {'id': 249,
#   'date': '2016-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 549400,
#   'medianRentalPriceLA': '2588',
#   'regionus': 'United States',
#   'medianhomepriceus': 193900,
#   'medianRentalPriceUS': '1388'},
#  {'id': 250,
#   'date': '2017-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 553600,
#   'medianRentalPriceLA': '2590',
#   'regionus': 'United States',
#   'medianhomepriceus': 195200,
#   'medianRentalPriceUS': '1385'},
#  {'id': 251,
#   'date': '2017-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 556300,
#   'medianRentalPriceLA': '2591',
#   'regionus': 'United States',
#   'medianhomepriceus': 196400,
#   'medianRentalPriceUS': '1383'},
#  {'id': 252,
#   'date': '2017-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 558700,
#   'medianRentalPriceLA': '2593',
#   'regionus': 'United States',
#   'medianhomepriceus': 197600,
#   'medianRentalPriceUS': '1384'},
#  {'id': 253,
#   'date': '2017-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 561100,
#   'medianRentalPriceLA': '2598',
#   'regionus': 'United States',
#   'medianhomepriceus': 199000,
#   'medianRentalPriceUS': '1387'},
#  {'id': 254,
#   'date': '2017-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 563400,
#   'medianRentalPriceLA': '2609',
#   'regionus': 'United States',
#   'medianhomepriceus': 200300,
#   'medianRentalPriceUS': '1392'},
#  {'id': 255,
#   'date': '2017-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 566000,
#   'medianRentalPriceLA': '2626',
#   'regionus': 'United States',
#   'medianhomepriceus': 201300,
#   'medianRentalPriceUS': '1399'},
#  {'id': 256,
#   'date': '2017-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 569100,
#   'medianRentalPriceLA': '2647',
#   'regionus': 'United States',
#   'medianhomepriceus': 202300,
#   'medianRentalPriceUS': '1409'},
#  {'id': 257,
#   'date': '2017-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 573100,
#   'medianRentalPriceLA': '2666',
#   'regionus': 'United States',
#   'medianhomepriceus': 203500,
#   'medianRentalPriceUS': '1420'},
#  {'id': 258,
#   'date': '2017-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 577400,
#   'medianRentalPriceLA': '2681',
#   'regionus': 'United States',
#   'medianhomepriceus': 204700,
#   'medianRentalPriceUS': '1428'},
#  {'id': 259,
#   'date': '2017-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 581500,
#   'medianRentalPriceLA': '2691',
#   'regionus': 'United States',
#   'medianhomepriceus': 205700,
#   'medianRentalPriceUS': '1429'},
#  {'id': 260,
#   'date': '2017-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 585100,
#   'medianRentalPriceLA': '2697',
#   'regionus': 'United States',
#   'medianhomepriceus': 206700,
#   'medianRentalPriceUS': '1426'},
#  {'id': 261,
#   'date': '2017-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 589200,
#   'medianRentalPriceLA': '2702',
#   'regionus': 'United States',
#   'medianhomepriceus': 207900,
#   'medianRentalPriceUS': '1420'},
#  {'id': 262,
#   'date': '2018-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 594700,
#   'medianRentalPriceLA': '2708',
#   'regionus': 'United States',
#   'medianhomepriceus': 209400,
#   'medianRentalPriceUS': '1414'},
#  {'id': 263,
#   'date': '2018-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 600600,
#   'medianRentalPriceLA': '2716',
#   'regionus': 'United States',
#   'medianhomepriceus': 211200,
#   'medianRentalPriceUS': '1411'},
#  {'id': 264,
#   'date': '2018-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 603600,
#   'medianRentalPriceLA': '2724',
#   'regionus': 'United States',
#   'medianhomepriceus': 212800,
#   'medianRentalPriceUS': '1412'},
#  {'id': 265,
#   'date': '2018-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 604400,
#   'medianRentalPriceLA': '2732',
#   'regionus': 'United States',
#   'medianhomepriceus': 214100,
#   'medianRentalPriceUS': '1414'},
#  {'id': 266,
#   'date': '2018-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 605100,
#   'medianRentalPriceLA': '2739',
#   'regionus': 'United States',
#   'medianhomepriceus': 215400,
#   'medianRentalPriceUS': '1416'},
#  {'id': 267,
#   'date': '2018-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 606400,
#   'medianRentalPriceLA': '2742',
#   'regionus': 'United States',
#   'medianhomepriceus': 216600,
#   'medianRentalPriceUS': '1416'},
#  {'id': 268,
#   'date': '2018-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 607600,
#   'medianRentalPriceLA': '2743',
#   'regionus': 'United States',
#   'medianhomepriceus': 217700,
#   'medianRentalPriceUS': '1415'},
#  {'id': 269,
#   'date': '2018-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 609200,
#   'medianRentalPriceLA': '2743',
#   'regionus': 'United States',
#   'medianhomepriceus': 218900,
#   'medianRentalPriceUS': '1415'},
#  {'id': 270,
#   'date': '2018-09',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 611700,
#   'medianRentalPriceLA': '2743',
#   'regionus': 'United States',
#   'medianhomepriceus': 220300,
#   'medianRentalPriceUS': '1414'},
#  {'id': 271,
#   'date': '2018-10',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 615100,
#   'medianRentalPriceLA': '2748',
#   'regionus': 'United States',
#   'medianhomepriceus': 221800,
#   'medianRentalPriceUS': '1417'},
#  {'id': 272,
#   'date': '2018-11',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 617900,
#   'medianRentalPriceLA': '2767',
#   'regionus': 'United States',
#   'medianhomepriceus': 223400,
#   'medianRentalPriceUS': '1426'},
#  {'id': 273,
#   'date': '2018-12',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 620300,
#   'medianRentalPriceLA': '2791',
#   'regionus': 'United States',
#   'medianhomepriceus': 225000,
#   'medianRentalPriceUS': '1438'},
#  {'id': 274,
#   'date': '2019-01',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 623200,
#   'medianRentalPriceLA': '2812',
#   'regionus': 'United States',
#   'medianhomepriceus': 226400,
#   'medianRentalPriceUS': '1447'},
#  {'id': 275,
#   'date': '2019-02',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 624400,
#   'medianRentalPriceLA': '2819',
#   'regionus': 'United States',
#   'medianhomepriceus': 227500,
#   'medianRentalPriceUS': '1450'},
#  {'id': 276,
#   'date': '2019-03',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 623200,
#   'medianRentalPriceLA': '2819',
#   'regionus': 'United States',
#   'medianhomepriceus': 227800,
#   'medianRentalPriceUS': '1453'},
#  {'id': 277,
#   'date': '2019-04',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 621800,
#   'medianRentalPriceLA': '2819',
#   'regionus': 'United States',
#   'medianhomepriceus': 227700,
#   'medianRentalPriceUS': '1456'},
#  {'id': 278,
#   'date': '2019-05',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 621600,
#   'medianRentalPriceLA': '2817',
#   'regionus': 'United States',
#   'medianhomepriceus': 227700,
#   'medianRentalPriceUS': '1457'},
#  {'id': 279,
#   'date': '2019-06',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 621000,
#   'medianRentalPriceLA': '2817',
#   'regionus': 'United States',
#   'medianhomepriceus': 228300,
#   'medianRentalPriceUS': '1460'},
#  {'id': 280,
#   'date': '2019-07',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 620800,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 229000,
#   'medianRentalPriceUS': None},
#  {'id': 281,
#   'date': '2019-08',
#   'regionla': 'Los Angeles County',
#   'medianhomepricela': 621600,
#   'medianRentalPriceLA': None,
#   'regionus': 'United States',
#   'medianhomepriceus': 229600,
#   'medianRentalPriceUS': None}]

# %%
realwealthdict = {"population":population, "employment":employment, "monthlylistings":monthlylistings, "medianincome": medianincome,"home_rentalprice":home_rentalprice}

# homerentalpriceData = {"home_rentalprice": id, date, regionla, medianhomepricela, medianRentalPriceLA, regionus, medianhomepriceus, medianRentalPriceUS}
